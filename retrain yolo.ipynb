# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9ym9pFfZRllzdTzxnN2b")
project = rf.workspace("projet-3a").project("fire-extinguisher-detection")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics

# %%
# !nvidia-smi
# Out:
# Fri Dec  6 09:38:12 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install --upgrade tensorflow
# !pip install --upgrade tensorboard
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.3/615.3 MB 921.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 100.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.1
#     Uninstalling tensorflow-2.17.1:
#       Successfully uninstalled tensorflow-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.18.0 which is incompatible.
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# ERROR: Operation cancelled by user

# %%
from ultralytics import YOLO
model = YOLO("/content/best.pt")
train = model.train(data='/content/Fire-extinguisher-detection-3/data.yaml',epochs=300, imgsz=640,device=0)
# Out:
# Ultralytics 8.3.43 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image
Image("/content/runs/detect/train8/train_batch2.jpg",width=600)

# %%
Image("/content/runs/detect/train8/results.png",width=600)

# %%
Image("/content/runs/detect/train8/val_batch1_labels.jpg",width=600)

# %%
bt = YOLO('/content/runs/detect/train8/weights/best.pt')
image_path = "/content/p1.jpg"
results = bt.predict(source=image_path, imgsz=640, device=0, save=True)
# Out:
# image 1/1 /content/p1.jpg: 640x640 (no detections), 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
results = bt.predict(source='/content/f2.jpg', imgsz=640, device=0, save=True)
# Out:
# image 1/1 /content/f2.jpg: 384x640 1 Fire-extinguisher, 17.2ms
# Speed: 2.7ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
Image("/content/runs/detect/predict2/f2.jpg",width=600)

# %%
from google.colab import files
import shutil

# Path to the folder you want to download
folder_path = "/content/runs/detect/train8"

# Compress the folder into a .zip file
shutil.make_archive("my_folder", 'zip', folder_path)

# Download the .zip file
files.download("my_folder.zip")
